# %% [markdown]
# <a href="https://colab.research.google.com/github/ktapsw-Danish/khyber-tuition-academy/blob/main/Making_AI_Applications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
import pandas as pd

df = pd.read_csv("advertising (1).csv")
print(df.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(df.shape)
print(df.isnull().sum())
print(df.columns)
# Out:
# (200, 4)
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
X = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

model = Pipeline([
    ('poly', PolynomialFeatures(degree=2, include_bias=False)),
    ('linear', LinearRegression())
])

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(include_bias=False)),
#                 ('linear', LinearRegression())])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R² Score:", r2)
# Out:
# MAE: 0.9033713382791676
# MSE: 1.4425426369010854
# RMSE: 1.2010589647894416
# R² Score: 0.9533174341074886

# %%
custom_input = pd.DataFrame({
    'TV': [100],
    'Radio': [20],
    'Newspaper': [30]
})

prediction = model.predict(custom_input)

print("Predicted Sales:", prediction[0])
# Out:
# Predicted Sales: 12.532522552193548

# %%
import joblib

joblib.dump(model, "polynomial_sales_model.pkl")
# Out:
# ['polynomial_sales_model.pkl']
